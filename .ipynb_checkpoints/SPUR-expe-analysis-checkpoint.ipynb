# %%
import pandas as pd 
import numpy as np

df_spur = pd.read_csv("experiments-SPUR.csv")

# %%
df_spur.shape
# Out:
# (70, 15)

# %%
df_spur
# Out:
#                   start_time  \
# 0   Tue May 28 10:22:32 2019
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4   Tue May 28 10:28:33 2019
# 5   Tue May 28 10:28:35 2019
# 6                        NaN
# 7                        NaN
# 8                        NaN
# 9                        NaN
# 10                       NaN
# 11  Tue May 28 10:38:35 2019
# 12  Tue May 28 10:38:35 2019
# 13  Tue May 28 10:38:36 2019
# 14  Tue May 28 10:38:36 2019
# 15                       NaN
# 16  Tue May 28 10:40:36 2019
# 17  Tue May 28 10:40:36 2019
# 18  Tue May 28 10:40:36 2019
# 19  Tue May 28 10:40:36 2019
# 20  Tue May 28 10:40:36 2019
# 21                       NaN
# 22  Tue May 28 10:42:36 2019
# 23  Tue May 28 10:42:37 2019
# 24                       NaN
# 25  Tue May 28 10:44:39 2019
# 26  Tue May 28 10:44:39 2019
# 27  Tue May 28 10:44:40 2019
# 28  Tue May 28 10:44:40 2019
# 29  Tue May 28 10:44:41 2019
# ..                       ...
# ...

# %%
df_spur.query("timeout == False").shape
# Out:
# (49, 15)
