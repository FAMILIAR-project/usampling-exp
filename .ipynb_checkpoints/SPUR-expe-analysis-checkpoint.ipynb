# %%
import pandas as pd 
import numpy as np

df_spur = pd.read_csv("experiments-SPUR-fla.csv")
#df_spur = pd.read_csv("experiments-SPUR-blasted.csv")
#df_spur = pd.read_csv("experiments-SPUR-V7.csv")
#df_spur = pd.read_csv("experiments-SPUR-V3.csv")
#df_spur = pd.read_csv("experiments-SPUR-V15.csv")
#df_spur = pd.read_csv("experiments-SPUR-fmeasy.csv")
#df_spur = pd.read_csv("experiments-SPUR-fm.csv")

# %%
df_spur.shape
# Out:
# (117, 15)

# %%
df_spur
# Out:
#                    start_time  \
# 0    Tue May 28 15:43:31 2019
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# 5                         NaN
# 6    Tue May 28 15:44:01 2019
# 7                         NaN
# 8                         NaN
# 9    Tue May 28 15:44:16 2019
# 10                        NaN
# 11   Tue May 28 15:44:25 2019
# 12   Tue May 28 15:44:25 2019
# 13                        NaN
# 14                        NaN
# 15                        NaN
# 16                        NaN
# 17                        NaN
# 18                        NaN
# 19                        NaN
# 20                        NaN
# 21                        NaN
# 22                        NaN
# 23                        NaN
# 24                        NaN
# 25                        NaN
# 26                        NaN
# 27                        NaN
# 28                        NaN
# 29                        NaN
# ...

# %%
df_spur.query("timeout == False").shape
# Out:
# (11, 15)
